# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
url = 'https://www.nhs.uk/conditions/'
driver = webdriver.Chrome()
driver.get(url)

agree_button = driver.find_element(By.XPATH, '//*[@id="nhsuk-cookie-banner__link_accept_analytics"]')
driver.execute_script('arguments[0].click()', agree_button)
# agree_button.click()
time.sleep(2)

# %%
def get_div():
    div_li = dict()
    divs = driver.find_elements(By.XPATH, '//*[@id="maincontent"]/div/div/article/ol/div')
    div_count = len(divs)
    print(div_count)

    for li_i in range(div_count):
        div_lis = driver.find_elements(By.XPATH, f'//*[@id="maincontent"]/div/div/article/ol/div[{li_i}]/div/ul/li')
        div_li_count = len(div_lis)
        div_li[li_i] = div_li_count
        # print(li_i, div_li_count)

    return div_li

# %%
div_li = get_div()
div_li
# Out:
# 52
# {0: 0,
#  1: 96,
#  2: 0,
#  3: 101,
#  4: 0,
#  5: 119,
#  6: 0,
#  7: 58,
#  8: 0,
#  9: 56,
#  10: 0,
#  11: 38,
#  12: 0,
#  13: 39,
#  14: 0,
#  15: 108,
#  16: 0,
#  17: 34,
#  18: 0,
#  19: 8,
#  20: 0,
#  21: 16,
#  22: 0,
#  23: 51,
#  24: 0,
#  25: 65,
#  26: 0,
#  27: 36,
#  28: 0,
#  29: 21,
#  30: 0,
#  31: 112,
#  32: 0,
#  33: 2,
#  34: 0,
#  35: 33,
#  36: 0,
#  37: 112,
#  38: 0,
#  39: 70,
#  40: 0,
#  41: 15,
#  42: 0,
#  43: 27,
#  44: 0,
#  45: 21,
#  46: 0,
#  47: 1,
#  48: 0,
#  49: 1,
#  50: 0,
#  51: 1}

# %% [markdown]
# ##### All together

# %%
def get_title_intro():
    intr_xpath = '//div/div//p'
    sctn_title = driver.title.split('-')[0].strip()
    try:
        sctn_intro = driver.find_element(By.XPATH, intr_xpath).text
    except:
        sctn_intro = None
    return sctn_title, sctn_intro

# %%
def get_question_answer(tt, ito):
    sctn_xpath = '//main/article/div/div/section'
    titles_xpath = '//main/article/div/div/section/h2'
    sctns = driver.find_elements(By.XPATH, sctn_xpath)
    titles = driver.find_elements(By.XPATH, titles_xpath)

    ttl_dict = dict()
    ttl_index_list = list()
    for si in range(1, len(sctns) + 1):
        sctn_xa = f'//main/article/div/div/section[{si}]/h2'
        try:
            sctn_id = driver.find_element(By.XPATH, sctn_xa)
            ttl_dict[si] = sctn_id.text
            ttl_index_list.append(si)
            # print(si, sctn_id.text, sctn_id.get_attribute('id'))
        except:
            pass

    qas = list()
    qai_start = [tt, ito]
    for ti in ttl_index_list:
        qai = qai_start.copy()
        sctn_xb = f'//main/article/div/div/section[{ti}]'
        sctn_content = driver.find_element(By.XPATH, sctn_xb)
        qai.append(ttl_dict[ti])
        qai.append(sctn_content.text[len(ttl_dict[ti]) + 1:])
        qas.append(qai)
        # print(ti, ttl_dict[ti])
        # print(sctn_content.text[len(ttl_dict[ti]) + 1:])
    # print(qas)
    return qas

# %%
def click_link_all(div_idx, li_idx):
    time.sleep(2)
    cdtn_link_xpath = f'//main/div/div/article/ol/div[{div_idx}]/div/ul/li[{li_idx}]/a'
    cdtn_link = driver.find_element(By.XPATH, cdtn_link_xpath)
    driver.execute_script('arguments[0].click()', cdtn_link)
    time.sleep(2)
    print(driver.title)

    title, intro = get_title_intro()
    if intro:
        qas = get_question_answer(title, intro)
        new_row = qas.copy()
    else:
        new_row = None

    driver.back()
    driver.execute_script("window.scrollTo(0, 0);")
    time.sleep(2)

    return new_row

# %%
import csv
headers = ['title', 'introduction', 'question', 'answer']

with open('nhs.csv', 'w', newline='', encoding='utf-8') as file:
    wtr = csv.writer(file)
    wtr.writerow(headers)

    for div_idx, li in div_li.items():
        if li == 0:
            continue
        for li_idx in range(1, li + 1):
            print(div_idx, li_idx, end='\t')
            nr = click_link_all(div_idx, li_idx)
            if nr:
                wtr.writerows(nr)
            else:
                pass
# Out:
# 1 1	Abdominal aortic aneurysm screening - NHS
# 1 2	Abdominal aortic aneurysm - NHS
# 1 3	Abdominal aortic aneurysm - NHS
# 1 4	Abdominal aortic aneurysm screening - NHS
# 1 5	Abortion - NHS
# 1 6	Acanthosis nigricans - NHS
# 1 7	Achalasia - NHS
# 1 8	Acid and chemical burns - NHS
# 1 9	Reflux in babies - NHS
# 1 10	Acne - NHS
# 1 11	Acoustic neuroma (vestibular schwannoma) - NHS
# 1 12	Acromegaly - NHS
# 1 13	Actinic keratoses (solar keratoses) - NHS
# 1 14	Actinomycosis - NHS
# 1 15	Acupuncture - NHS
# 1 16	Acute cholecystitis - NHS
# 1 17	Acute kidney injury - NHS
# 1 18	Acute lymphoblastic leukaemia - NHS
# 1 19	Acute myeloid leukaemia - NHS
# 1 20	Acute pancreatitis - NHS
# 1 21	Acute respiratory distress syndrome (ARDS) - NHS
# 1 22	Addison's disease - NHS
# 1 23	Adenoidectomy - NHS
# 1 24	Adenomyosis - NHS
# 1 25	Age-related cataracts - NHS
# 1 26	Age-related macular degeneration (AMD) - NHS
# 1 27	Agoraphobia - NHS
# 1 28	Albinism - NHS
# 1 29	Alcohol misuse - NHS
# ...

# %%
import csv
headers = ['title', 'introduction', 'question', 'answer']

div_id = 3
li_total = div_li[div_id]
print(li_total)

with open('example_test.csv', 'w', newline='', encoding='utf-8') as file:
    wtr = csv.writer(file)
    wtr.writerow(headers)
    for lii in range(1, div_li[div_id] + 1):
        print(div_id, lii, end='\t')
        nr = click_link_all(div_id, lii)
        if nr:
            wtr.writerows(nr)
        else:
            pass
# Out:
# 101
# 3 1	Baby - NHS
# 3 2	Back pain - NHS
# 3 3	Bacterial vaginosis - NHS
# 3 4	Bad breath - NHS
# 3 5	Baker's cyst - NHS
# 3 6	Balanitis - NHS
# 3 7	Barium enema - NHS
# 3 8	Bartholin's cyst - NHS
# 3 9	What is non-melanoma skin cancer? - NHS
# 3 10	Log in
# 3 11	Bedbugs - NHS
# 3 12	Bedwetting in children - NHS
# 3 13	Behçet's disease - NHS
# 3 14	Diarrhoea and vomiting - NHS
# 3 15	Bell's palsy - NHS
# 3 16	Benign brain tumour (non-cancerous) - NHS
# 3 17	Benign prostate enlargement - NHS
# 3 18	Beta blockers - NHS
# 3 19	Bile duct cancer - NHS
# 3 20	Schistosomiasis (bilharzia) - NHS
# 3 21	Binge eating disorder - NHS
# 3 22	Biopsy - NHS
# 3 23	Bipolar disorder - NHS
# 3 24	Bird flu - NHS
# 3 25	Birthmarks - NHS
# 3 26	Animal and human bites - NHS
# 3 27	Black eye - NHS
# 3 28	Bladder cancer - NHS
# 3 29	Bladder pain syndrome (interstitial cystitis) - NHS
# 3 30	Bladder stones - NHS
# 3 31	Postmenopausal bleeding - NHS
# 3 32	Bleeding from the bottom (rectal bleeding) - NHS
# ...

# %%
import pandas as pd

df = pd.read_csv('nhs.csv', encoding='utf-8')
df
# Out:
#                                     title  \
# 0     Abdominal aortic aneurysm screening
# 1     Abdominal aortic aneurysm screening
# 2     Abdominal aortic aneurysm screening
# 3     Abdominal aortic aneurysm screening
# 4     Abdominal aortic aneurysm screening
# ...                                   ...
# 5048                           Zika virus
# 5049                           Zika virus
# 5050                           Zika virus
# 5051                           Zika virus
# 5052                           Zika virus
#
#                                            introduction  \
# 0     Abdominal aortic aneurysm (AAA) screening is a...
# 1     Abdominal aortic aneurysm (AAA) screening is a...
# 2     Abdominal aortic aneurysm (AAA) screening is a...
# 3     Abdominal aortic aneurysm (AAA) screening is a...
# 4     Abdominal aortic aneurysm (AAA) screening is a...
# ...                                                 ...
# 5048  Zika virus is mainly spread by mosquitoes foun...
# ...

# %% [markdown]
# ##### Whole

# %%
def click_link(div_idx, li_idx):

    time.sleep(2)
    cdtn_link_xpath = f'//main/div/div/article/ol/div[{div_idx}]/div/ul/li[{li_idx}]/a'
    cdtn_link = driver.find_element(By.XPATH, cdtn_link_xpath)
    # cdtn_link.click()
    driver.execute_script('arguments[0].click()', cdtn_link)
    time.sleep(2)
    print('Current title:', driver.title)

    driver.back()
    driver.execute_script("window.scrollTo(0, 0);")
    time.sleep(2)

# %%
for div_idx, li in div_li.items():
    if li == 0:
        continue
    for li_idx in range(1, li + 1):
        print(div_idx, li_idx)
        click_link(div_idx, li_idx)

        if li_idx == 20:
            break
# Out:
# 1 1
# Current title: Abdominal aortic aneurysm screening - NHS
# 1 2
# Current title: Abdominal aortic aneurysm - NHS
# 1 3
# Current title: Abdominal aortic aneurysm - NHS
# 1 4
# Current title: Abdominal aortic aneurysm screening - NHS
# 1 5
# Current title: Abortion - NHS
# 1 6
# Current title: Acanthosis nigricans - NHS
# 1 7
# Current title: Achalasia - NHS
# 1 8
# Current title: Acid and chemical burns - NHS
# 1 9
# Current title: Reflux in babies - NHS
# 1 10
# Current title: Acne - NHS
# 1 11
# Current title: Acoustic neuroma (vestibular schwannoma) - NHS
# 1 12
# Current title: Acromegaly - NHS
# 1 13
# Current title: Actinic keratoses (solar keratoses) - NHS
# 1 14
# Current title: Actinomycosis - NHS
# 1 15
# Current title: Acupuncture - NHS
# 1 16
# Current title: Acute cholecystitis - NHS
# 1 17
# Current title: Acute kidney injury - NHS
# 1 18
# Current title: Acute lymphoblastic leukaemia - NHS
# 1 19
# Current title: Acute myeloid leukaemia - NHS
# 1 20
# ...

# %% [markdown]
# ##### Function Testing

# %%
cdtn_link = driver.find_element(By.XPATH, '//main/div/div/article/ol/div[15]/div/ul/li[50]/a')  # 15 10
driver.execute_script('arguments[0].click()', cdtn_link)

# %%
# name_xpath = '//main/div/div/h1'
# intr_xpath = '//main/article/div/div/section/p'
#name_xpath = '//div/div/h1'
# /html/body/div[1]/main/article/div/div/section[1]/p[1]
intr_xpath = '//div/div//p'
sctn_title = driver.title.split('-')[0].strip()
#sctn_title = driver.find_element(By.XPATH, name_xpath).text
sctn_intro = driver.find_element(By.XPATH, intr_xpath).text

print(sctn_title, len(sctn_title))
print(sctn_intro)
# Out:
# Herbal medicines 16
# Herbal medicines are those with active ingredients made from plant parts, such as leaves, roots or flowers. But being "natural" doesn't necessarily mean they're safe for you to take.

# %%
sctn_xpath = '//main/article/div/div/section'
titles_xpath = '//main/article/div/div/section/h2'
sctns = driver.find_elements(By.XPATH, sctn_xpath)
titles = driver.find_elements(By.XPATH, titles_xpath)

print(len(sctns))
for title_idx, ti in enumerate(titles):
    print(title_idx, ti.text, ti.get_attribute('id'))
# Out:
# 7
# 0 Potential issues with herbal medicines
# 1 Who should avoid herbal medicines?
# 2 Herbal medicines and surgery
# 3 What to look for when buying a herbal medicine
# 4 Risks of buying herbal medicines online or by mail order
# 5 Reporting side effects

# %%
ttl_dict = dict()
ttl_index_list = list()
for si in range(1, len(sctns) + 1):
    sctn_xa = f'//main/article/div/div/section[{si}]/h2'
    try:
        sctn_id = driver.find_element(By.XPATH, sctn_xa)
        ttl_dict[si] = sctn_id.text
        ttl_index_list.append(si)
        print(si, sctn_id.text, sctn_id.get_attribute('id'))
    except:
        pass
# Out:
# 2 Potential issues with herbal medicines
# 3 Who should avoid herbal medicines?
# 4 Herbal medicines and surgery
# 5 What to look for when buying a herbal medicine
# 6 Risks of buying herbal medicines online or by mail order
# 7 Reporting side effects

# %%
ttl_index_list, ttl_dict
# Out:
# ([2, 3, 4, 5, 6, 7],
#  {2: 'Potential issues with herbal medicines',
#   3: 'Who should avoid herbal medicines?',
#   4: 'Herbal medicines and surgery',
#   5: 'What to look for when buying a herbal medicine',
#   6: 'Risks of buying herbal medicines online or by mail order',
#   7: 'Reporting side effects'})

# %%
for ti in ttl_index_list:
    sctn_xb = f'//main/article/div/div/section[{ti}]'
    sctn_content = driver.find_element(By.XPATH, sctn_xb)
    print(ti, ttl_dict[ti])
    print(sctn_content.text[len(ttl_dict[ti]) + 1:])
    # for sci in sctn_content:
        # print(ti, sci.text)
# Out:
# 2 Potential issues with herbal medicines
# If you're taking, or plan to take, any herbal medicines, be aware of the following:
# They may cause problems if you're taking other medicines. They could make the other medicine less effective or cause the other medicine to trigger unexpected side effects.
# You may experience a bad reaction or side effects after taking a herbal medicine.
# Not all herbal medicines are regulated. Remedies specially prepared for individuals don't need a licence, and those manufactured outside the UK may not be subject to regulation.
# Evidence for the effectiveness of herbal medicines is generally very limited. Although some people find them helpful, in many cases their use tends to be based on traditional use rather than scientific research.
# Certain groups of people should be particularly wary of taking herbal medicines.
# 3 Who should avoid herbal medicines?
# Taking a herbal medicine may not be suitable for:
# ...

# %% [markdown]
# ##### Others

# %%
aa = 'Abdominal aortic aneurysm screening - NHS'
ab = aa.split('-')
ac = ab[0].strip()
ac
# Out:
# 'Abdominal aortic aneurysm screening'

# %%
import csv
headers = ['title', 'introduction']

with open('example.csv', 'w', newline='') as f:
    wtr = csv.writer(f)
    wtr.writerow(headers)

# %%
import pandas as pd

df = pd.read_csv('example.csv')
df
# Out:
# Empty DataFrame
# Columns: [title, introduction]
# Index: []
